# %%
import numpy as np
import beta_neuron as an
import importlib
importlib.reload(an)
# Out:
# <module 'beta_neuron' from '/home/owner/Projects/the_worm_project/beta_neuron.py'>

# %%
from matplotlib import pyplot as plt

# %%
V = np.array([-40.0, -40.0])
G_syn = np.array([[0.0, 100.0], [100.0, 0.0]])
G_gap = np.array([[0.0, 0.0], [0.0,0.0]])

net = an.NeuronNetwork(V, G_syn, G_gap, v_clamp=np.array([0, 1]))

# %%
net.simple_run(0.001, 3.0)
# Out:
# ##########

# %% [markdown]
# ## Synapse loop

# %%
volts = np.array([40.0, -40.0])
syn = np.array([[0.0, 100.0], [100.0, 0.0]])
gap = np.array([[0.0, 0.0], [0.0,0.0]])
sim = an.NeuronNetwork(volts, syn, gap)
sim.simple_run(0.001, 5.0, limiter=False)
sim.show_all_data()
# Out:
# ##########

# %% [markdown]
# ## Synapse x Voltage response

# %%
simulations = []

for j in range(1, 20, 4):

    results = []
    for i in range(0, 300, 20):
        volts = np.array([-200.0 + i, -40.0])
        syn = np.array([[0.0, 100.0], [j * 100.0, 0.0]])
        gap = np.array([[0.0, 0.0], [0.0,0.0]])
        sim = an.NeuronNetwork(volts, syn, gap, v_clamp=np.array([0, 1]))
        sim.simple_run(0.001, 3.0, show_progress=False)
        results.append(sim.syn_store[-1][0])
    simulations.append(results)

# %%
volts_x = [-200.0 + i for i in range(0, 300, 20)]
for sim in simulations:
    plt.plot(volts_x, sim)
plt.show()

# %% [markdown]
# ## Gap Jn Voltage Response

# %%
simulations = []

for j in range(1, 20, 2):

    results = []
    for i in range(0, 300, 10):
        volts = np.array([-200.0 + i, -40.0])
        syn = np.array([[0.0, 0.0], [0.0, 0.0]])
        gap = np.array([[0.0, j * 100.0], [j * 100.0,0.0]])
        sim = an.NeuronNetwork(volts, syn, gap, v_clamp=np.array([0, 1]))
        sim.simple_run(0.001, 3.0, show_progress=False)
        results.append(sim.gap_store[-1][0])
    simulations.append(results)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 11
#       9     gap = np.array([[0.0, j * 100.0], [j * 100.0,0.0]])
#      10     sim = an.NeuronNetwork(volts, syn, gap, v_clamp=np.array([0, 1]))
# ---> 11     sim.simple_run(0.001, 3.0, show_progress=False)
#      12     results.append(sim.gap_store[-1][0])
#      13 simulations.append(results)
#
# File ~/Projects/the_worm_project/beta_neuron.py:191, in NeuronNetwork.simple_run(self, delta_t, run_time, show_progress)
#     188 if show_progress and i % (time_range // 10) == 0:
#     189     print("#", end="")
# --> 191 self.step(delta_t, input_current)
#
# File ~/Projects/the_worm_project/beta_neuron.py:151, in NeuronNetwork.step(self, time_step, input_current)
#     149 V_infinity = V_inf(synapse_coeffiecnt, synapse_intercept, gap_coefficent, gap_intercept)
#     150 d_V_m = delta_V_m(self.big_V, leak_current, gap_current, synapse_current, input_current)
# --> 151 d_s = delta_s(self.big_V, self.big_s)
#     153 # Clamp
#     154 V_diff = V_infinity - self.big_V
#
# File ~/Projects/the_worm_project/beta_neuron.py:59, in delta_s(V_m, s_i)
#      56 beta = 0.125
#      57 V_th = -15 #??
# ---> 59 sig = 1 / (1 + np.exp(-beta * (V_m - V_th)))
#      61 return a_r * sig * (1 - s_i) - a_d * s_i
#
# KeyboardInterrupt:

# %%
volts_x = [-200.0 + i for i in range(0, 300, 10)]
for sim in simulations:
    plt.plot(volts_x, sim)
plt.show()

# %% [markdown]
# # Numeric Stability

# %%
results = []
deltas = [0.2, 0.1, 0.05, 0.01, 0.001, 0.0001]
I_gen = lambda t : np.array([0]) if t < 2.0 or t > 3.0 else np.array([50])
for delta_t in deltas:
    volts = np.array([-60.0])
    gap = np.array([[0.0]])
    syn = np.array([[0.0]])
    sim = an.NeuronNetwork(volts, gap, syn)
    sim.adv_run(delta_t, 5.0, I_gen)
    results.append([sim.t_store, sim.V_store])
# Out:
# ###############################################################

# %%
for i, res in enumerate(results):
    plt.plot(res[0], res[1], label=f"d_t = {deltas[i]}")
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ### With Huge Current

# %%
results = []
deltas = [0.1, 0.05, 0.01, 0.001, 0.0001]
I_gen = lambda t : np.array([0]) if t < 2.0 or t > 3.0 else np.array([5000000000])
for delta_t in deltas:
    volts = np.array([-60.0])
    gap = np.array([[0.0]])
    syn = np.array([[0.0]])
    sim = an.NeuronNetwork(volts, gap, syn)
    sim.adv_run(delta_t, 5.0, I_gen)
    results.append([sim.t_store, sim.V_store])

for i, res in enumerate(results):
    plt.plot(res[0], res[1], label=f"d_t = {deltas[i]}")
plt.legend(loc='best')
plt.show()
# Out:
# ##################################################
